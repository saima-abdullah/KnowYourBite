# %%
import pandas as pd
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS

# %% [markdown]
# ### Load Additives Data

# %%
#Load the additives data
df_additives = pd.read_csv('../data/Ingredients_list_banned.csv')
df_additives.head()
# Out:
#              Ingredient    Purpose  \
# 0  Acesulfame potassium  Sweetener
# 1         Allura Red AC   Coloring
# 2             Aloe vera  Flavoring
# 3              Amaranth   Coloring
# 4            Aspartame   Sweetener
#
#                                       Health_concern  \
# 0  Cancer, Hormone Disruption, Risks to Pregnant ...
# 1               May cause hyperactivity in children.
# 2                                             Cancer
# 3                               carcinogenic effects
# 4              Cancer,Linked to headaches, dizziness
#
#                      Alternative_names
# 0     Ace-K, Acesulfame K, E950,Sunett
# 1                          E129,Red 40
# 2  Aloe barbadensis, Aloe leaf extract
# 3                       E123,Red No. 2
# 4  Equal, NutraSweet, E951, AminoSweet

# %% [markdown]
# #### Data Cleaning

# %%
# Rename the column names to required format
df_additives.columns=df_additives.columns.str.lower()

# %%
# Combining the 'ingredient' and 'alternate_names' to have a combine list of unhealthy ingredients
df_additives['bad_ingredients'] = df_additives['ingredient']+ ','+df_additives['alternative_names'].fillna('')
df_additives.head(40)
# Out:
#                               ingredient                 purpose  \
# 0                   Acesulfame potassium               Sweetener
# 1                          Allura Red AC                Coloring
# 2                              Aloe vera               Flavoring
# 3                               Amaranth                Coloring
# 4                             Aspartame                Sweetener
# 5                       Azodicarbonamide                Coloring
# 6                     Brilliant Black BN                   other
# 7              Brominated vegetable oil               Emulsifier
# 8              Butylated hydroxyanisole             Preservative
# 9                       Caramel coloring                Coloring
# 10                Carboxymethylcellulose             Stabilizers
# 11                            Carmoisine                Coloring
# 12                           Carrageenan             Stabilizers
# 13                       Chloramphenicol                   other
# 14                             Cyclamate               Sweetener
# 15                           Erythrosine                Coloring
# 16                         Ginkgo biloba  Vitamins & Supplements
# 17                  Monosodium Glutamate                  Flavor
# 18                               Olestra   Oil & Oil Substitutes
# 19                       Phosphoric Acid            Preservative
# 20  Polyoxyethylene Sorbitan Monooleate              Stabilizers
# 21                            Ponceau 4R                Coloring
# 22                     Potassium Nitrite            Preservative
# 23                     Potassium bromate                   Other
# 24                      Potassium iodate                   Other
# 25                             Saccharin               Sweetener
# 26                       Sodium Benzoate            Preservative
# 27                       Sodium nitrate             Preservative
# 28                            Sucralose                Sweetener
# 29                        Sulfur Dioxide            Preservative
# 30                     Sunset Yellow FCF                Coloring
# 31                   Synthetic food dyes                Coloring
# 32                             Tartrazin                Coloring
# 33                      Titanium dioxide                Coloring
# 34            hydrogenated vegetable oil   Oil & Oil Substitutes
# 35                tert-butylhydroquinone            Preservative
# 36                   Brilliant Blue FCF.                Coloring
# 37                       Propionic Acid             Preservative
#
#                                        health_concern  \
# 0   Cancer, Hormone Disruption, Risks to Pregnant ...
# 1                May cause hyperactivity in children.
# 2                                              Cancer
# 3                                carcinogenic effects
# 4               Cancer,Linked to headaches, dizziness
# 5    Linked to respiratory issues and classified a...
# 6     Linked to hyperactivity and allergic reactions.
# 7                           Neurological & Behavioral
# 8                                              Cancer
# 9                                              Cancer
# 10  Associated with gut inflammation and microbiot...
# 11             Linked to hyperactivity and allergies.
# 12   Linked to gut inflammation and digestive issues.
# 13           Associated with serious blood disorders.
# 14                                             Cancer
# 15          Associated with hyperactivity in children
# 16                             Cancer, cardiovascular
# 17     headaches and nausea in sensitive individuals.
# 18                     can cause digestive discomfort
# 19  Excessive intake has been associated with a hi...
# 20   May cause allergic reactions and gut irritation.
# 21  Suspected of being a carcinogen; linked to all...
# 22                                             Cancer
# 23  Digestive,Classified as a possible human carci...
# 24  Digestive, Excessive consumption can lead to t...
# 25                                          Digestive
# 26                                             Cancer
# 27                                             Cancer
# 28                                             Cancer
# 29  Can trigger asthma attacks or allergic reactio...
# 30    May cause hyperactivity and allergic reactions.
# 31                                                NaN
# 32  Associated with hyperactivity in children and ...
# 33                                             Cancer
# 34                Increase the risk of heart disease.
# 35  Linked to hyperactivity and behavioral issues ...
# 36  can cause allergic reactions, hyperactivity in...
# 37   Linked to hyperactivity and behavioral issues...
#
#                                     alternative_names  \
# 0                    Ace-K, Acesulfame K, E950,Sunett
# 1                                         E129,Red 40
# 2                 Aloe barbadensis, Aloe leaf extract
# 3                                      E123,Red No. 2
# 4                 Equal, NutraSweet, E951, AminoSweet
# 5         ADA,Dough Conditioner,Flour Treatment Agent
# 6                                      E151 ,Black PN
# 7   BVO,Brominated Soybean Oil, Brominated Palm Oi...
# 8   BHA, E320,Butylated Hydroxyanisole,E321,BHT,Bu...
# 9                        E150d, Sulfite ammonia,E150c
# 10                                               E466
# 11                     E122,Azorubine,Cochineal Red A
# 12                                               E407
# 13                                                CAP
# 14                      E952,Cyclamic Acid,Cyclamates
# 15    Red Dye No. 3,E127, FD&C Red No. 3, Food Red 14
# 16                                                NaN
# 17                                E621, MSG,Glutamate
# 18                                              olean
# 19                                               E338
# 20                                E433,Polysorbate 80
# 21                                               E124
# 22                                      E249,Nitrites
# 23  E924, Bromated flour, KBrO3,Bromic Acid Potass...
# 24  E202, Sorbistat-K, KIO₃, Iodic Acid Potassium ...
# 25                              E954,Saccharin Sodium
# 26                             E211,Benzoic Acid Salt
# 27     E250, Chile saltpeter, Nitrate of soda,Nitrite
# 28                    Splenda, E955, Trichlorosucrose
# 29  Sulfites,E220,Sulfur Dioxide,E221,Sodium Sulfi...
# 30  E110,Orange Yellow S, Yellow 6,Yellow Dye No. ...
# 31                                                NaN
# 32  E102, Yellow 5,Yellow Dye No. 5,FD&C Yellow No...
# 33      E171, TiO2, Titanium(IV) oxide,Titanium Oxide
# 34  PHOs,Trans Fats, Partially Hydrogenated Soybea...
# 35                        TBHQ,E319 ,Antioxidant 319,
# 36  Blue 1,FD&C Blue No. 1,E133,Tert-Butylhydroqui...
# 37  E280,E283,E281,E282,Sodium Propionate,Calcium ...
#
#                                       bad_ingredients
# 0   Acesulfame potassium,Ace-K, Acesulfame K, E950...
# 1                           Allura Red AC,E129,Red 40
# 2       Aloe vera,Aloe barbadensis, Aloe leaf extract
# 3                             Amaranth,E123,Red No. 2
# 4      Aspartame ,Equal, NutraSweet, E951, AminoSweet
# 5   Azodicarbonamide,ADA,Dough Conditioner,Flour T...
# 6                   Brilliant Black BN,E151 ,Black PN
# 7   Brominated vegetable oil ,BVO,Brominated Soybe...
# 8   Butylated hydroxyanisole ,BHA, E320,Butylated ...
# 9       Caramel coloring,E150d, Sulfite ammonia,E150c
# 10                        Carboxymethylcellulose,E466
# 11          Carmoisine,E122,Azorubine,Cochineal Red A
# 12                                   Carrageenan,E407
# 13                                Chloramphenicol,CAP
# 14            Cyclamate,E952,Cyclamic Acid,Cyclamates
# 15  Erythrosine,Red Dye No. 3,E127, FD&C Red No. 3...
# 16                                     Ginkgo biloba,
# 17           Monosodium Glutamate,E621, MSG,Glutamate
# 18                                      Olestra,olean
# 19                               Phosphoric Acid,E338
# 20  Polyoxyethylene Sorbitan Monooleate ,E433,Poly...
# 21                                    Ponceau 4R,E124
# 22                    Potassium Nitrite,E249,Nitrites
# 23  Potassium bromate,E924, Bromated flour, KBrO3,...
# 24  Potassium iodate,E202, Sorbistat-K, KIO₃, Iodi...
# 25                    Saccharin,E954,Saccharin Sodium
# 26             Sodium Benzoate,E211,Benzoic Acid Salt
# 27  Sodium nitrate ,E250, Chile saltpeter, Nitrate...
# 28         Sucralose ,Splenda, E955, Trichlorosucrose
# 29  Sulfur Dioxide,Sulfites,E220,Sulfur Dioxide,E2...
# 30  Sunset Yellow FCF,E110,Orange Yellow S, Yellow...
# 31                               Synthetic food dyes,
# 32  Tartrazin,E102, Yellow 5,Yellow Dye No. 5,FD&C...
# 33  Titanium dioxide,E171, TiO2, Titanium(IV) oxid...
# 34  hydrogenated vegetable oil,PHOs,Trans Fats, Pa...
# 35  tert-butylhydroquinone,TBHQ,E319 ,Antioxidant ...
# 36   Brilliant Blue FCF.,Blue 1,FD&C Blue No. 1,E1...
# 37   Propionic Acid ,E280,E283,E281,E282,Sodium Pr...

# %%
#Check the null values
df_additives.isna().sum()
# Out:
# ingredient           0
# purpose              0
# health_concern       1
# alternative_names    2
# bad_ingredients      0
# dtype: int64

# %%
#Check the data types
df_additives.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ingredient         38 non-null     object
#  1   purpose            38 non-null     object
#  2   health_concern     37 non-null     object
#  3   alternative_names  36 non-null     object
#  4   bad_ingredients    38 non-null     object
# dtypes: object(5)
# memory usage: 1.6+ KB

# %%
#Summary statistics of additives dataset
df_additives.describe(include='all')
# Out:
#                   ingredient   purpose health_concern  \
# count                     38        38             37
# unique                    38        11             29
# top     Acesulfame potassium  Coloring         Cancer
# freq                       1        12              9
#
#                        alternative_names  \
# count                                 36
# unique                                36
# top     Ace-K, Acesulfame K, E950,Sunett
# freq                                   1
#
#                                           bad_ingredients
# count                                                  38
# unique                                                 38
# top     Acesulfame potassium,Ace-K, Acesulfame K, E950...
# freq                                                    1

# %% [markdown]
# ### Load Food Products Dataset

# %%
#df_food = pd.read_csv('../data/ingredients v1.csv')
df_food = pd.read_csv('../data/openfoodfacts_products_world.csv')
df_food.head(20)
# Out:
#                                 brands  \
# 0                          Mutti,POLPA
# 1                    Maïzena, Unilever
# 2                              Barilla
# 3                               Tipiak
# 4   Zespri,Sungold,Catania,ALDI Zespri
# 5                                Kraft
# 6                               Quaker
# 7                                Kraft
# 8                          La Molisana
# 9                            Vita Coco
# 10                       Terra Delyssa
# 11                     Clément Faugier
# 12                   Fleurs des Champs
# 13                            Lustucru
# 14                         Refresh,UFC
# 15    Nature's Path Organic - Kirkland
# 16                         Quaker Oats
# 17                         Earth's Own
# 18                Post, Shredded Wheat
# 19               Aldi,Roland Mills Ost
#
#                                  product_name  \
# 0                            pulpe de tomates
# 1      Maizena Fleur de Maïs Sans Gluten 400g
# 2                            Lasagne all'uovo
# 3                      Fine chapelure de pain
# 4                                Kiwi Sungold
# 5                        Creamy Peanut Butter
# 6           So Simple Apple And Blueberry imp
# 7                        Smooth Peanut Butter
# 8                          Penne rigate nº 20
# 9                               Coconut Water
# 10    Huile d'olive vierge extra (Biologique)
# 11              Crème de Marrons de L'Ardèche
# 12                                       Maïs
# 13                                        NaN
# 14                              Coconut Water
# 15           Ancient Grains Probiotic Granola
# 16                    Quick 1-minute Oats imp
# 17                               Oat Original
# 18  Spoon Size Shredded Wheat & Bran - Canada
# 19                      Farine de Blé type 45
#
#                                            categories  \
# 0   Pflanzliche Lebensmittel und Getränke,Pflanzli...
# 1   Plant-based foods and beverages, Plant-based f...
# 2   Cibi e bevande a base vegetale, Cibi a base ve...
# 3   Aliments et boissons à base de végétaux,Alimen...
# 4   Aliments et boissons à base de végétaux,Alimen...
# 5   Plant-based foods and beverages, Plant-based f...
# 6   Plant-based foods and beverages, Plant-based f...
# 7   Plant-based foods and beverages, Plant-based f...
# 8   Cibi e bevande a base vegetale, Cibi a base ve...
# 9   Beverages and beverages preparations,Plant-bas...
# 10  Aliments et boissons à base de végétaux, Alime...
# 11  Aliments et boissons à base de végétaux, Alime...
# 12  Aliments et boissons à base de végétaux, Alime...
# 13  Plant-based foods and beverages, Plant-based f...
# 14  Beverages and beverages preparations,Plant-bas...
# 15  Plant-based foods and beverages,Plant-based fo...
# 16  Plant-based foods and beverages,Plant-based fo...
# 17  Plant-based foods and beverages, Beverages, Pl...
# 18  Plant-based foods and beverages, Plant-based f...
# 19  Aliments et boissons à base de végétaux,Alimen...
#
#                                             countries  \
# 0   Australien,Österreich,Belgien,Kanada,Frankreic...
# 1   Belgique, Canada, France, Martinique, La Réuni...
# 2   Belgium,Canada,Croatia,France,Germany,Greece,H...
# 3                                       Canada,France
# 4   Belgique,Canada,France,Allemagne,Pologne,Espag...
# 5                                       Canada,France
# 6                                              Canada
# 7                                       Canada,France
# 8                                        Canada,Italy
# 9   Canada,France,United Kingdom,United States, World
# 10                                      Canada,France
# 11                                      Canada,France
# 12                                      Canada,France
# 13                        Kanada, Frankreich, Germany
# 14  Canada,France,Germany,New Zealand,Singapore,Un...
# 15                               Canada,United States
# 16                 Canada,France,United States, World
# 17                        Canada,United States, World
# 18                                      Canada, World
# 19                                      Canada,France
#
#                                      food_groups_tags  \
# 0       ['en:fruits-and-vegetables', 'en:vegetables']
# 1           ['en:cereals-and-potatoes', 'en:cereals']
# 2           ['en:cereals-and-potatoes', 'en:cereals']
# 3             ['en:cereals-and-potatoes', 'en:bread']
# 4           ['en:fruits-and-vegetables', 'en:fruits']
# 5                   ['en:fats-and-sauces', 'en:fats']
# 6   ['en:cereals-and-potatoes', 'en:breakfast-cere...
# 7           ['en:cereals-and-potatoes', 'en:legumes']
# 8           ['en:cereals-and-potatoes', 'en:cereals']
# 9          ['en:beverages', 'en:sweetened-beverages']
# 10                  ['en:fats-and-sauces', 'en:fats']
# 11                     ['en:salty-snacks', 'en:nuts']
# 12          ['en:cereals-and-potatoes', 'en:cereals']
# 13          ['en:cereals-and-potatoes', 'en:cereals']
# 14       ['en:beverages', 'en:unsweetened-beverages']
# 15  ['en:cereals-and-potatoes', 'en:breakfast-cere...
# 16  ['en:cereals-and-potatoes', 'en:breakfast-cere...
# 17  ['en:beverages', 'en:plant-based-milk-substitu...
# 18  ['en:cereals-and-potatoes', 'en:breakfast-cere...
# 19          ['en:cereals-and-potatoes', 'en:cereals']
#
#                         food_groups  \
# 0                     en:vegetables
# 1                        en:cereals
# 2                        en:cereals
# 3                          en:bread
# 4                         en:fruits
# 5                           en:fats
# 6              en:breakfast-cereals
# 7                        en:legumes
# 8                        en:cereals
# 9            en:sweetened-beverages
# 10                          en:fats
# 11                          en:nuts
# 12                       en:cereals
# 13                       en:cereals
# 14         en:unsweetened-beverages
# 15             en:breakfast-cereals
# 16             en:breakfast-cereals
# 17  en:plant-based-milk-substitutes
# 18             en:breakfast-cereals
# 19                       en:cereals
#
#                                      ingredients_text  \
# 0                                tomatoes 99.8%, salt
# 1                                     Amidon de maïs.
# 2   Semola di grano duro, uova fresche di categori...
# 3   Farine de blé (gluten), sel, levure, Traces po...
# 4                                           Kiwifruit
# 5   _Select roasted peanuts_, Soybean oil, Sugars ...
# 6   Quaker Wholegrain Rolled Oats (77%), Sugar, Dr...
# 7   Select roasted peanuts, Soybean oil, Corn malt...
# 8                       pasta di semola di grano duro
# 9   Coconut Water (99%), Fructose (&lt;1%), Vitami...
# 10  Huile d'olive vierge Extra Biologique première...
# 11  Châtaignes (50%), sucre, marrons glacés, sirop...
# 12                                     maïs, eau, sel
# 13                          Parboiled long grain rice
# 14                        100% natural coconut water.
# 15  Whole grain rolled oats*, cane sugar*, soy oil...
# 16                           whole grain rolled oats,
# 17  Oat base (filtered water, oats), Sunflower oil...
# 18                 Whole grain wheat, Wheat bran, BHT
# 19                                     Farine de blé.
#
#                       category_name country
# 0   Plant-based foods and beverages  canada
# 1   Plant-based foods and beverages  canada
# 2   Plant-based foods and beverages  canada
# 3   Plant-based foods and beverages  canada
# 4   Plant-based foods and beverages  canada
# 5   Plant-based foods and beverages  canada
# 6   Plant-based foods and beverages  canada
# 7   Plant-based foods and beverages  canada
# 8   Plant-based foods and beverages  canada
# 9   Plant-based foods and beverages  canada
# 10  Plant-based foods and beverages  canada
# 11  Plant-based foods and beverages  canada
# 12  Plant-based foods and beverages  canada
# 13  Plant-based foods and beverages  canada
# 14  Plant-based foods and beverages  canada
# 15  Plant-based foods and beverages  canada
# 16  Plant-based foods and beverages  canada
# 17  Plant-based foods and beverages  canada
# 18  Plant-based foods and beverages  canada
# 19  Plant-based foods and beverages  canada

# %% [markdown]
# #### Data Cleaning

# %%
# Check the column names
df_food.columns
# Out:
# Index(['brands', 'product_name', 'categories', 'countries', 'food_groups_tags',
#        'food_groups', 'ingredients_text', 'category_name', 'country'],
#       dtype='object')

# %%
#Shape of food products data
df_food.shape
# Out:
# (29414, 9)

# %%
#Check for missing values 
df_food.isna().sum()
# Out:
# brands              1712
# product_name         540
# categories             0
# countries              0
# food_groups_tags       0
# food_groups         1053
# ingredients_text    3686
# category_name          0
# country                0
# dtype: int64

# %%
#drop data where product name is missing 
df_food.dropna(subset=['ingredients_text'],inplace=True)
df_food.shape
# Out:
# (25728, 9)

# %%
df_food.isna().sum()
# Out:
# brands              625
# product_name        271
# categories            0
# countries             0
# food_groups_tags      0
# food_groups         757
# ingredients_text      0
# category_name         0
# country               0
# dtype: int64

# %%
#Food dataset columns datatype
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25728 entries, 0 to 29413
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brands            25103 non-null  object
#  1   product_name      25457 non-null  object
#  2   categories        25728 non-null  object
#  3   countries         25728 non-null  object
#  4   food_groups_tags  25728 non-null  object
#  5   food_groups       24971 non-null  object
#  6   ingredients_text  25728 non-null  object
#  7   category_name     25728 non-null  object
#  8   country           25728 non-null  object
# dtypes: object(9)
# memory usage: 2.0+ MB

# %%
#Summary statistics of food products dataset
df_food.describe(include= 'all')
# Out:
#         brands            product_name  \
# count    25103                   25457
# unique    4130                    9831
# top     Auchan  Extra Virgin Olive Oil
# freq      3603                      66
#
#                                                categories countries  \
# count                                               25728     25728
# unique                                               6667      1132
# top     Breakfasts, Spreads, Sweet spreads, Bee produc...    Canada
# freq                                                  342      3669
#
#                          food_groups_tags food_groups        ingredients_text  \
# count                               25728       24971                   25728
# unique                                 44          43                   10364
# top     ['en:sugary-snacks', 'en:sweets']   en:sweets  Extra virgin olive oil
# freq                                 2366        2366                      58
#
#                category_name country
# count                  25728   25728
# unique                   100       3
# top     Cereals and potatoes   world
# freq                     297    9290

# %% [markdown]
# -----

# %% [markdown]
# ### Text Preprocesing

# %%
def preprocess_text(text):
    # Check if text is NaN (float), return empty string if true
    if pd.isna(text):
        return ''
    # Split text by commas, strip spaces, and process each component
    components = text.split(',')
    processed_components = [component.strip().lower() for component in components]
    # Join the processed components back with commas
    return ', '.join(processed_components)

# %%
df_additives['bad_ingredients_preprocessed'] = df_additives['bad_ingredients'].apply(preprocess_text)
df_additives
# Out:
#                               ingredient                 purpose  \
# 0                   Acesulfame potassium               Sweetener
# 1                          Allura Red AC                Coloring
# 2                              Aloe vera               Flavoring
# 3                               Amaranth                Coloring
# 4                             Aspartame                Sweetener
# 5                       Azodicarbonamide                Coloring
# 6                     Brilliant Black BN                   other
# 7              Brominated vegetable oil               Emulsifier
# 8              Butylated hydroxyanisole             Preservative
# 9                       Caramel coloring                Coloring
# 10                Carboxymethylcellulose             Stabilizers
# 11                            Carmoisine                Coloring
# 12                           Carrageenan             Stabilizers
# 13                       Chloramphenicol                   other
# 14                             Cyclamate               Sweetener
# 15                           Erythrosine                Coloring
# 16                         Ginkgo biloba  Vitamins & Supplements
# 17                  Monosodium Glutamate                  Flavor
# 18                               Olestra   Oil & Oil Substitutes
# 19                       Phosphoric Acid            Preservative
# 20  Polyoxyethylene Sorbitan Monooleate              Stabilizers
# 21                            Ponceau 4R                Coloring
# 22                     Potassium Nitrite            Preservative
# 23                     Potassium bromate                   Other
# 24                      Potassium iodate                   Other
# 25                             Saccharin               Sweetener
# 26                       Sodium Benzoate            Preservative
# 27                       Sodium nitrate             Preservative
# 28                            Sucralose                Sweetener
# 29                        Sulfur Dioxide            Preservative
# 30                     Sunset Yellow FCF                Coloring
# 31                   Synthetic food dyes                Coloring
# 32                             Tartrazin                Coloring
# 33                      Titanium dioxide                Coloring
# 34            hydrogenated vegetable oil   Oil & Oil Substitutes
# 35                tert-butylhydroquinone            Preservative
# 36                   Brilliant Blue FCF.                Coloring
# 37                       Propionic Acid             Preservative
#
#                                        health_concern  \
# 0   Cancer, Hormone Disruption, Risks to Pregnant ...
# 1                May cause hyperactivity in children.
# 2                                              Cancer
# 3                                carcinogenic effects
# 4               Cancer,Linked to headaches, dizziness
# 5    Linked to respiratory issues and classified a...
# 6     Linked to hyperactivity and allergic reactions.
# 7                           Neurological & Behavioral
# 8                                              Cancer
# 9                                              Cancer
# 10  Associated with gut inflammation and microbiot...
# 11             Linked to hyperactivity and allergies.
# 12   Linked to gut inflammation and digestive issues.
# 13           Associated with serious blood disorders.
# 14                                             Cancer
# 15          Associated with hyperactivity in children
# 16                             Cancer, cardiovascular
# 17     headaches and nausea in sensitive individuals.
# 18                     can cause digestive discomfort
# 19  Excessive intake has been associated with a hi...
# 20   May cause allergic reactions and gut irritation.
# 21  Suspected of being a carcinogen; linked to all...
# 22                                             Cancer
# 23  Digestive,Classified as a possible human carci...
# 24  Digestive, Excessive consumption can lead to t...
# 25                                          Digestive
# 26                                             Cancer
# 27                                             Cancer
# 28                                             Cancer
# 29  Can trigger asthma attacks or allergic reactio...
# 30    May cause hyperactivity and allergic reactions.
# 31                                                NaN
# 32  Associated with hyperactivity in children and ...
# 33                                             Cancer
# 34                Increase the risk of heart disease.
# 35  Linked to hyperactivity and behavioral issues ...
# 36  can cause allergic reactions, hyperactivity in...
# 37   Linked to hyperactivity and behavioral issues...
#
#                                     alternative_names  \
# 0                    Ace-K, Acesulfame K, E950,Sunett
# 1                                         E129,Red 40
# 2                 Aloe barbadensis, Aloe leaf extract
# 3                                      E123,Red No. 2
# 4                 Equal, NutraSweet, E951, AminoSweet
# 5         ADA,Dough Conditioner,Flour Treatment Agent
# 6                                      E151 ,Black PN
# 7   BVO,Brominated Soybean Oil, Brominated Palm Oi...
# 8   BHA, E320,Butylated Hydroxyanisole,E321,BHT,Bu...
# 9                        E150d, Sulfite ammonia,E150c
# 10                                               E466
# 11                     E122,Azorubine,Cochineal Red A
# 12                                               E407
# 13                                                CAP
# 14                      E952,Cyclamic Acid,Cyclamates
# 15    Red Dye No. 3,E127, FD&C Red No. 3, Food Red 14
# 16                                                NaN
# 17                                E621, MSG,Glutamate
# 18                                              olean
# 19                                               E338
# 20                                E433,Polysorbate 80
# 21                                               E124
# 22                                      E249,Nitrites
# 23  E924, Bromated flour, KBrO3,Bromic Acid Potass...
# 24  E202, Sorbistat-K, KIO₃, Iodic Acid Potassium ...
# 25                              E954,Saccharin Sodium
# 26                             E211,Benzoic Acid Salt
# 27     E250, Chile saltpeter, Nitrate of soda,Nitrite
# 28                    Splenda, E955, Trichlorosucrose
# 29  Sulfites,E220,Sulfur Dioxide,E221,Sodium Sulfi...
# 30  E110,Orange Yellow S, Yellow 6,Yellow Dye No. ...
# 31                                                NaN
# 32  E102, Yellow 5,Yellow Dye No. 5,FD&C Yellow No...
# 33      E171, TiO2, Titanium(IV) oxide,Titanium Oxide
# 34  PHOs,Trans Fats, Partially Hydrogenated Soybea...
# 35                        TBHQ,E319 ,Antioxidant 319,
# 36  Blue 1,FD&C Blue No. 1,E133,Tert-Butylhydroqui...
# 37  E280,E283,E281,E282,Sodium Propionate,Calcium ...
#
#                                       bad_ingredients  \
# 0   Acesulfame potassium,Ace-K, Acesulfame K, E950...
# 1                           Allura Red AC,E129,Red 40
# 2       Aloe vera,Aloe barbadensis, Aloe leaf extract
# 3                             Amaranth,E123,Red No. 2
# 4      Aspartame ,Equal, NutraSweet, E951, AminoSweet
# 5   Azodicarbonamide,ADA,Dough Conditioner,Flour T...
# 6                   Brilliant Black BN,E151 ,Black PN
# 7   Brominated vegetable oil ,BVO,Brominated Soybe...
# 8   Butylated hydroxyanisole ,BHA, E320,Butylated ...
# 9       Caramel coloring,E150d, Sulfite ammonia,E150c
# 10                        Carboxymethylcellulose,E466
# 11          Carmoisine,E122,Azorubine,Cochineal Red A
# 12                                   Carrageenan,E407
# 13                                Chloramphenicol,CAP
# 14            Cyclamate,E952,Cyclamic Acid,Cyclamates
# 15  Erythrosine,Red Dye No. 3,E127, FD&C Red No. 3...
# 16                                     Ginkgo biloba,
# 17           Monosodium Glutamate,E621, MSG,Glutamate
# 18                                      Olestra,olean
# 19                               Phosphoric Acid,E338
# 20  Polyoxyethylene Sorbitan Monooleate ,E433,Poly...
# 21                                    Ponceau 4R,E124
# 22                    Potassium Nitrite,E249,Nitrites
# 23  Potassium bromate,E924, Bromated flour, KBrO3,...
# 24  Potassium iodate,E202, Sorbistat-K, KIO₃, Iodi...
# 25                    Saccharin,E954,Saccharin Sodium
# 26             Sodium Benzoate,E211,Benzoic Acid Salt
# 27  Sodium nitrate ,E250, Chile saltpeter, Nitrate...
# 28         Sucralose ,Splenda, E955, Trichlorosucrose
# 29  Sulfur Dioxide,Sulfites,E220,Sulfur Dioxide,E2...
# 30  Sunset Yellow FCF,E110,Orange Yellow S, Yellow...
# 31                               Synthetic food dyes,
# 32  Tartrazin,E102, Yellow 5,Yellow Dye No. 5,FD&C...
# 33  Titanium dioxide,E171, TiO2, Titanium(IV) oxid...
# 34  hydrogenated vegetable oil,PHOs,Trans Fats, Pa...
# 35  tert-butylhydroquinone,TBHQ,E319 ,Antioxidant ...
# 36   Brilliant Blue FCF.,Blue 1,FD&C Blue No. 1,E1...
# 37   Propionic Acid ,E280,E283,E281,E282,Sodium Pr...
#
#                          bad_ingredients_preprocessed
# 0   acesulfame potassium, ace-k, acesulfame k, e95...
# 1                         allura red ac, e129, red 40
# 2      aloe vera, aloe barbadensis, aloe leaf extract
# 3                           amaranth, e123, red no. 2
# 4      aspartame, equal, nutrasweet, e951, aminosweet
# 5   azodicarbonamide, ada, dough conditioner, flou...
# 6                  brilliant black bn, e151, black pn
# 7   brominated vegetable oil, bvo, brominated soyb...
# 8   butylated hydroxyanisole, bha, e320, butylated...
# 9     caramel coloring, e150d, sulfite ammonia, e150c
# 10                       carboxymethylcellulose, e466
# 11       carmoisine, e122, azorubine, cochineal red a
# 12                                  carrageenan, e407
# 13                               chloramphenicol, cap
# 14         cyclamate, e952, cyclamic acid, cyclamates
# 15  erythrosine, red dye no. 3, e127, fd&c red no....
# 16                                    ginkgo biloba,
# 17         monosodium glutamate, e621, msg, glutamate
# 18                                     olestra, olean
# 19                              phosphoric acid, e338
# 20  polyoxyethylene sorbitan monooleate, e433, pol...
# 21                                   ponceau 4r, e124
# 22                  potassium nitrite, e249, nitrites
# 23  potassium bromate, e924, bromated flour, kbro3...
# 24  potassium iodate, e202, sorbistat-k, kio₃, iod...
# 25                  saccharin, e954, saccharin sodium
# 26           sodium benzoate, e211, benzoic acid salt
# 27  sodium nitrate, e250, chile saltpeter, nitrate...
# 28         sucralose, splenda, e955, trichlorosucrose
# 29  sulfur dioxide, sulfites, e220, sulfur dioxide...
# 30  sunset yellow fcf, e110, orange yellow s, yell...
# 31                              synthetic food dyes,
# 32  tartrazin, e102, yellow 5, yellow dye no. 5, f...
# 33  titanium dioxide, e171, tio2, titanium(iv) oxi...
# 34  hydrogenated vegetable oil, phos, trans fats, ...
# 35  tert-butylhydroquinone, tbhq, e319, antioxidan...
# 36  brilliant blue fcf., blue 1, fd&c blue no. 1, ...
# 37  propionic acid, e280, e283, e281, e282, sodium...

# %%
# Apply text preprocessing to food products dataset
df_food['processed_ingredients'] = df_food['ingredients_text'].apply(preprocess_text)
df_food.head()
# Out:
#                                brands                            product_name  \
# 0                         Mutti,POLPA                        pulpe de tomates
# 1                   Maïzena, Unilever  Maizena Fleur de Maïs Sans Gluten 400g
# 2                             Barilla                        Lasagne all'uovo
# 3                              Tipiak                  Fine chapelure de pain
# 4  Zespri,Sungold,Catania,ALDI Zespri                            Kiwi Sungold
#
#                                           categories  \
# 0  Pflanzliche Lebensmittel und Getränke,Pflanzli...
# 1  Plant-based foods and beverages, Plant-based f...
# 2  Cibi e bevande a base vegetale, Cibi a base ve...
# 3  Aliments et boissons à base de végétaux,Alimen...
# 4  Aliments et boissons à base de végétaux,Alimen...
#
#                                            countries  \
# 0  Australien,Österreich,Belgien,Kanada,Frankreic...
# 1  Belgique, Canada, France, Martinique, La Réuni...
# 2  Belgium,Canada,Croatia,France,Germany,Greece,H...
# 3                                      Canada,France
# 4  Belgique,Canada,France,Allemagne,Pologne,Espag...
#
#                                 food_groups_tags    food_groups  \
# 0  ['en:fruits-and-vegetables', 'en:vegetables']  en:vegetables
# 1      ['en:cereals-and-potatoes', 'en:cereals']     en:cereals
# 2      ['en:cereals-and-potatoes', 'en:cereals']     en:cereals
# 3        ['en:cereals-and-potatoes', 'en:bread']       en:bread
# 4      ['en:fruits-and-vegetables', 'en:fruits']      en:fruits
#
#                                     ingredients_text  \
# 0                               tomatoes 99.8%, salt
# 1                                    Amidon de maïs.
# 2  Semola di grano duro, uova fresche di categori...
# 3  Farine de blé (gluten), sel, levure, Traces po...
# 4                                          Kiwifruit
#
#                      category_name country  \
# 0  Plant-based foods and beverages  canada
# 1  Plant-based foods and beverages  canada
# 2  Plant-based foods and beverages  canada
# 3  Plant-based foods and beverages  canada
# 4  Plant-based foods and beverages  canada
#
#                                processed_ingredients
# 0                               tomatoes 99.8%, salt
# 1                                    amidon de maïs.
# 2  semola di grano duro, uova fresche di categori...
# 3  farine de blé (gluten), sel, levure, traces po...
# 4                                          kiwifruit

# %%
# Apply text preprocessing to additives dataset
df_additives['processed_bad_ingredients'] = df_additives['bad_ingredients'].apply(preprocess_and_split_ingredients)
df_additives.head(30)
# Out:
#                               ingredient                 purpose  \
# 0                   Acesulfame potassium               Sweetener
# 1                          Allura Red AC                Coloring
# 2                              Aloe vera               Flavoring
# 3                               Amaranth                Coloring
# 4                             Aspartame                Sweetener
# 5                       Azodicarbonamide                Coloring
# 6                     Brilliant Black BN                   other
# 7              Brominated vegetable oil               Emulsifier
# 8              Butylated hydroxyanisole             Preservative
# 9                       Caramel coloring                Coloring
# 10                Carboxymethylcellulose             Stabilizers
# 11                            Carmoisine                Coloring
# 12                           Carrageenan             Stabilizers
# 13                       Chloramphenicol                   other
# 14                             Cyclamate               Sweetener
# 15                           Erythrosine                Coloring
# 16                         Ginkgo biloba  Vitamins & Supplements
# 17                  Monosodium Glutamate                  Flavor
# 18                               Olestra   Oil & Oil Substitutes
# 19                       Phosphoric Acid            Preservative
# 20  Polyoxyethylene Sorbitan Monooleate              Stabilizers
# 21                            Ponceau 4R                Coloring
# 22                     Potassium Nitrite            Preservative
# 23                     Potassium bromate                   Other
# 24                      Potassium iodate                   Other
# 25                             Saccharin               Sweetener
# 26                       Sodium Benzoate            Preservative
# 27                       Sodium nitrate             Preservative
# 28                            Sucralose                Sweetener
# 29                        Sulfur Dioxide            Preservative
#
#                                        health_concern  \
# 0   Cancer, Hormone Disruption, Risks to Pregnant ...
# 1                May cause hyperactivity in children.
# 2                                              Cancer
# 3                                carcinogenic effects
# 4               Cancer,Linked to headaches, dizziness
# 5    Linked to respiratory issues and classified a...
# 6     Linked to hyperactivity and allergic reactions.
# 7                           Neurological & Behavioral
# 8                                              Cancer
# 9                                              Cancer
# 10  Associated with gut inflammation and microbiot...
# 11             Linked to hyperactivity and allergies.
# 12   Linked to gut inflammation and digestive issues.
# 13           Associated with serious blood disorders.
# 14                                             Cancer
# 15          Associated with hyperactivity in children
# 16                             Cancer, cardiovascular
# 17     headaches and nausea in sensitive individuals.
# 18                     can cause digestive discomfort
# 19  Excessive intake has been associated with a hi...
# 20   May cause allergic reactions and gut irritation.
# 21  Suspected of being a carcinogen; linked to all...
# 22                                             Cancer
# 23  Digestive,Classified as a possible human carci...
# 24  Digestive, Excessive consumption can lead to t...
# 25                                          Digestive
# 26                                             Cancer
# 27                                             Cancer
# 28                                             Cancer
# 29  Can trigger asthma attacks or allergic reactio...
#
#                                     alternative_names  \
# 0                    Ace-K, Acesulfame K, E950,Sunett
# 1                                         E129,Red 40
# 2                 Aloe barbadensis, Aloe leaf extract
# 3                                      E123,Red No. 2
# 4                 Equal, NutraSweet, E951, AminoSweet
# 5         ADA,Dough Conditioner,Flour Treatment Agent
# 6                                      E151 ,Black PN
# 7   BVO,Brominated Soybean Oil, Brominated Palm Oi...
# 8   BHA, E320,Butylated Hydroxyanisole,E321,BHT,Bu...
# 9                        E150d, Sulfite ammonia,E150c
# 10                                               E466
# 11                     E122,Azorubine,Cochineal Red A
# 12                                               E407
# 13                                                CAP
# 14                      E952,Cyclamic Acid,Cyclamates
# 15    Red Dye No. 3,E127, FD&C Red No. 3, Food Red 14
# 16                                                NaN
# 17                                E621, MSG,Glutamate
# 18                                              olean
# 19                                               E338
# 20                                E433,Polysorbate 80
# 21                                               E124
# 22                                      E249,Nitrites
# 23  E924, Bromated flour, KBrO3,Bromic Acid Potass...
# 24  E202, Sorbistat-K, KIO₃, Iodic Acid Potassium ...
# 25                              E954,Saccharin Sodium
# 26                             E211,Benzoic Acid Salt
# 27     E250, Chile saltpeter, Nitrate of soda,Nitrite
# 28                    Splenda, E955, Trichlorosucrose
# 29  Sulfites,E220,Sulfur Dioxide,E221,Sodium Sulfi...
#
#                                       bad_ingredients  \
# 0   Acesulfame potassium,Ace-K, Acesulfame K, E950...
# 1                           Allura Red AC,E129,Red 40
# 2       Aloe vera,Aloe barbadensis, Aloe leaf extract
# 3                             Amaranth,E123,Red No. 2
# 4      Aspartame ,Equal, NutraSweet, E951, AminoSweet
# 5   Azodicarbonamide,ADA,Dough Conditioner,Flour T...
# 6                   Brilliant Black BN,E151 ,Black PN
# 7   Brominated vegetable oil ,BVO,Brominated Soybe...
# 8   Butylated hydroxyanisole ,BHA, E320,Butylated ...
# 9       Caramel coloring,E150d, Sulfite ammonia,E150c
# 10                        Carboxymethylcellulose,E466
# 11          Carmoisine,E122,Azorubine,Cochineal Red A
# 12                                   Carrageenan,E407
# 13                                Chloramphenicol,CAP
# 14            Cyclamate,E952,Cyclamic Acid,Cyclamates
# 15  Erythrosine,Red Dye No. 3,E127, FD&C Red No. 3...
# 16                                     Ginkgo biloba,
# 17           Monosodium Glutamate,E621, MSG,Glutamate
# 18                                      Olestra,olean
# 19                               Phosphoric Acid,E338
# 20  Polyoxyethylene Sorbitan Monooleate ,E433,Poly...
# 21                                    Ponceau 4R,E124
# 22                    Potassium Nitrite,E249,Nitrites
# 23  Potassium bromate,E924, Bromated flour, KBrO3,...
# 24  Potassium iodate,E202, Sorbistat-K, KIO₃, Iodi...
# 25                    Saccharin,E954,Saccharin Sodium
# 26             Sodium Benzoate,E211,Benzoic Acid Salt
# 27  Sodium nitrate ,E250, Chile saltpeter, Nitrate...
# 28         Sucralose ,Splenda, E955, Trichlorosucrose
# 29  Sulfur Dioxide,Sulfites,E220,Sulfur Dioxide,E2...
#
#                          bad_ingredients_preprocessed  \
# 0   acesulfame potassium, ace-k, acesulfame k, e95...
# 1                         allura red ac, e129, red 40
# 2      aloe vera, aloe barbadensis, aloe leaf extract
# 3                           amaranth, e123, red no. 2
# 4      aspartame, equal, nutrasweet, e951, aminosweet
# 5   azodicarbonamide, ada, dough conditioner, flou...
# 6                  brilliant black bn, e151, black pn
# 7   brominated vegetable oil, bvo, brominated soyb...
# 8   butylated hydroxyanisole, bha, e320, butylated...
# 9     caramel coloring, e150d, sulfite ammonia, e150c
# 10                       carboxymethylcellulose, e466
# 11       carmoisine, e122, azorubine, cochineal red a
# 12                                  carrageenan, e407
# 13                               chloramphenicol, cap
# 14         cyclamate, e952, cyclamic acid, cyclamates
# 15  erythrosine, red dye no. 3, e127, fd&c red no....
# 16                                    ginkgo biloba,
# 17         monosodium glutamate, e621, msg, glutamate
# 18                                     olestra, olean
# 19                              phosphoric acid, e338
# 20  polyoxyethylene sorbitan monooleate, e433, pol...
# 21                                   ponceau 4r, e124
# 22                  potassium nitrite, e249, nitrites
# 23  potassium bromate, e924, bromated flour, kbro3...
# 24  potassium iodate, e202, sorbistat-k, kio₃, iod...
# 25                  saccharin, e954, saccharin sodium
# 26           sodium benzoate, e211, benzoic acid salt
# 27  sodium nitrate, e250, chile saltpeter, nitrate...
# 28         sucralose, splenda, e955, trichlorosucrose
# 29  sulfur dioxide, sulfites, e220, sulfur dioxide...
#
#                             processed_bad_ingredients
# 0   [acesulfame potassium, ace-k, acesulfame k, e9...
# 1                       [allura red ac, e129, red 40]
# 2    [aloe vera, aloe barbadensis, aloe leaf extract]
# 3                         [amaranth, e123, red no. 2]
# 4    [aspartame, equal, nutrasweet, e951, aminosweet]
# 5   [azodicarbonamide, ada, dough conditioner, flo...
# 6                [brilliant black bn, e151, black pn]
# 7   [brominated vegetable oil, bvo, brominated soy...
# 8   [butylated hydroxyanisole, bha, e320, butylate...
# 9   [caramel coloring, e150d, sulfite ammonia, e150c]
# 10                     [carboxymethylcellulose, e466]
# 11     [carmoisine, e122, azorubine, cochineal red a]
# 12                                [carrageenan, e407]
# 13                             [chloramphenicol, cap]
# 14       [cyclamate, e952, cyclamic acid, cyclamates]
# 15  [erythrosine, red dye no. 3, e127, fd&c red no...
# 16                                    [ginkgo biloba]
# 17       [monosodium glutamate, e621, msg, glutamate]
# 18                                   [olestra, olean]
# 19                            [phosphoric acid, e338]
# 20  [polyoxyethylene sorbitan monooleate, e433, po...
# 21                                 [ponceau 4r, e124]
# 22                [potassium nitrite, e249, nitrites]
# 23  [potassium bromate, e924, bromated flour, kbro...
# 24  [potassium iodate, e202, sorbistat-k, kio₃, io...
# 25                [saccharin, e954, saccharin sodium]
# 26         [sodium benzoate, e211, benzoic acid salt]
# 27  [sodium nitrate, e250, chile saltpeter, nitrat...
# 28       [sucralose, splenda, e955, trichlorosucrose]
# 29  [sulfur dioxide, sulfites, e220, sulfur dioxid...

# %%
#save the text processed data set 

df_additives.to_csv('../data/addtitives_processed.csv',index=False)
df_food.to_csv('../data/food_processed.csv',index = False)
