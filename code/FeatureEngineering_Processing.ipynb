# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Dataset

# %%
#Load the additives data
df_additives = pd.read_csv('../data/addtitives_processed.csv')
df_additives.head()
# Out:
#              ingredient    purpose  \
# 0  Acesulfame potassium  Sweetener
# 1         Allura Red AC   Coloring
# 2             Aloe vera  Flavoring
# 3              Amaranth   Coloring
# 4            Aspartame   Sweetener
#
#                                       health_concern  \
# 0  Cancer, Hormone Disruption, Risks to Pregnant ...
# 1               May cause hyperactivity in children.
# 2                                             Cancer
# 3                               carcinogenic effects
# 4              Cancer,Linked to headaches, dizziness
#
#                      alternative_names  \
# 0     Ace-K, Acesulfame K, E950,Sunett
# 1                          E129,Red 40
# 2  Aloe barbadensis, Aloe leaf extract
# 3                       E123,Red No. 2
# 4  Equal, NutraSweet, E951, AminoSweet
#
#                                      bad_ingredients  \
# 0  Acesulfame potassium,Ace-K, Acesulfame K, E950...
# 1                          Allura Red AC,E129,Red 40
# 2      Aloe vera,Aloe barbadensis, Aloe leaf extract
# 3                            Amaranth,E123,Red No. 2
# 4     Aspartame ,Equal, NutraSweet, E951, AminoSweet
#
#                         bad_ingredients_preprocessed  \
# 0  acesulfame potassium, ace-k, acesulfame k, e95...
# 1                        allura red ac, e129, red 40
# 2     aloe vera, aloe barbadensis, aloe leaf extract
# 3                          amaranth, e123, red no. 2
# 4     aspartame, equal, nutrasweet, e951, aminosweet
#
#                            processed_bad_ingredients
# 0  ['acesulfame potassium', 'ace-k', 'acesulfame ...
# 1                ['allura red ac', 'e129', 'red 40']
# 2  ['aloe vera', 'aloe barbadensis', 'aloe leaf e...
# 3                  ['amaranth', 'e123', 'red no. 2']
# 4  ['aspartame', 'equal', 'nutrasweet', 'e951', '...

# %%
#Load the food products dataset
df_food = pd.read_csv('../data/food_processed.csv')
df_food.head()
# Out:
#                                brands                            product_name  \
# 0                         Mutti,POLPA                        pulpe de tomates
# 1                   Maïzena, Unilever  Maizena Fleur de Maïs Sans Gluten 400g
# 2                             Barilla                        Lasagne all'uovo
# 3                              Tipiak                  Fine chapelure de pain
# 4  Zespri,Sungold,Catania,ALDI Zespri                            Kiwi Sungold
#
#                                           categories  \
# 0  Pflanzliche Lebensmittel und Getränke,Pflanzli...
# 1  Plant-based foods and beverages, Plant-based f...
# 2  Cibi e bevande a base vegetale, Cibi a base ve...
# 3  Aliments et boissons à base de végétaux,Alimen...
# 4  Aliments et boissons à base de végétaux,Alimen...
#
#                                            countries  \
# 0  Australien,Österreich,Belgien,Kanada,Frankreic...
# 1  Belgique, Canada, France, Martinique, La Réuni...
# 2  Belgium,Canada,Croatia,France,Germany,Greece,H...
# 3                                      Canada,France
# 4  Belgique,Canada,France,Allemagne,Pologne,Espag...
#
#                                 food_groups_tags    food_groups  \
# 0  ['en:fruits-and-vegetables', 'en:vegetables']  en:vegetables
# 1      ['en:cereals-and-potatoes', 'en:cereals']     en:cereals
# 2      ['en:cereals-and-potatoes', 'en:cereals']     en:cereals
# 3        ['en:cereals-and-potatoes', 'en:bread']       en:bread
# 4      ['en:fruits-and-vegetables', 'en:fruits']      en:fruits
#
#                                     ingredients_text  \
# 0                               tomatoes 99.8%, salt
# 1                                    Amidon de maïs.
# 2  Semola di grano duro, uova fresche di categori...
# 3  Farine de blé (gluten), sel, levure, Traces po...
# 4                                          Kiwifruit
#
#                      category_name country  \
# 0  Plant-based foods and beverages  canada
# 1  Plant-based foods and beverages  canada
# 2  Plant-based foods and beverages  canada
# 3  Plant-based foods and beverages  canada
# 4  Plant-based foods and beverages  canada
#
#                                processed_ingredients
# 0                               tomatoes 99.8%, salt
# 1                                    amidon de maïs.
# 2  semola di grano duro, uova fresche di categori...
# 3  farine de blé (gluten), sel, levure, traces po...
# 4                                          kiwifruit

# %% [markdown]
# ### Labelling food product based on the ingredients as healthy and not healthy

# %%
# bad ingredients into a single set
bad_ingredients_set = set()
df_additives['bad_ingredients_preprocessed'].str.split(', ').apply(bad_ingredients_set.update)
bad_ingredients_set.discard('')
bad_ingredients_set
# Out:
# {'ace-k',
#  'acesulfame k',
#  'acesulfame potassium',
#  'ada',
#  'allura red ac',
#  'aloe barbadensis',
#  'aloe leaf extract',
#  'aloe vera',
#  'amaranth',
#  'aminosweet',
#  'antioxidant 319',
#  'aspartame',
#  'azodicarbonamide',
#  'azorubine',
#  'benzoic acid salt',
#  'bha',
#  'bht',
#  'black pn',
#  'blue 1',
#  'brilliant black bn',
#  'brilliant blue fcf.',
#  'bromated flour',
#  'bromic acid potassium salt',
#  'brominated palm oil',
#  'brominated soybean oil',
#  'brominated vegetable fat',
#  'brominated vegetable oil',
#  'butylated hydroxyanisole',
#  'butylated hydroxytoluene',
#  'bvo',
#  'calcium bisulfite',
#  'calcium propionate',
#  'calcium sulfite',
#  'cap',
#  'caramel coloring',
#  'carboxymethylcellulose',
#  'carmoisine',
#  'carrageenan',
#  'chile saltpeter',
#  'chloramphenicol',
#  'cochineal red a',
#  'cyclamate',
#  'cyclamates',
#  'cyclamic acid',
#  'dough conditioner',
#  'e102',
#  'e110',
#  'e122',
#  'e123',
#  'e124',
#  'e127',
#  'e129',
#  'e133',
#  'e150c',
#  'e150d',
#  'e151',
#  'e171',
#  'e202',
#  'e211',
#  'e220',
#  'e221',
#  'e222',
#  'e223',
#  'e224',
#  'e225',
#  'e226',
#  'e227',
#  'e228',
#  'e249',
#  'e250',
#  'e280',
#  'e281',
#  'e282',
#  'e283',
#  'e319',
#  'e320',
#  'e321',
#  'e338',
#  'e407',
#  'e433',
#  'e466',
#  'e621',
#  'e924',
#  'e950',
#  'e951',
#  'e952',
#  'e954',
#  'e955',
#  'equal',
#  'erythrosine',
#  'fd&c blue no. 1',
#  'fd&c red no. 3',
#  'fd&c yellow no. 5',
#  'fd&c yellow no. 6',
#  'flour treatment agent',
#  'food red 14',
#  'food yellow 4.',
#  'ginkgo biloba',
#  'glutamate',
#  'hydrogenated vegetable oil',
#  'iodic acid potassium salt',
#  'kbro3',
#  'kio₃',
#  'monosodium glutamate',
#  'msg',
#  'nitrate of soda',
#  'nitrite',
#  'nitrites',
#  'nutrasweet',
#  'olean',
#  'olestra',
#  'orange yellow s',
#  'partially hydrogenated soybean oil',
#  'partially hydrogenated vegetable oil',
#  'phos',
#  'phosphoric acid',
#  'polyoxyethylene sorbitan monooleate',
#  'polysorbate 80',
#  'ponceau 4r',
#  'potassium bisulfite',
#  'potassium bromate',
#  'potassium iodate',
#  'potassium metabisulfite',
#  'potassium nitrite',
#  'potassium propionate',
#  'propionates',
#  'propionic acid',
#  'red 40',
#  'red dye no. 3',
#  'red no. 2',
#  'saccharin',
#  'saccharin sodium',
#  'sodium benzoate',
#  'sodium bisulfite',
#  'sodium metabisulfite',
#  'sodium nitrate',
#  'sodium propionate',
#  'sodium sulfite',
#  'sorbistat-k',
#  'splenda',
#  'sucralose',
#  'sulfite ammonia',
#  'sulfites',
#  'sulfur dioxide',
#  'sunett',
#  'sunset yellow fcf',
#  'synthetic food dyes',
#  'tartrazin',
#  'tbhq',
#  'tert-butylhydroquinone',
#  'tertiary butylhydroquinone',
#  'tio2',
#  'titanium dioxide',
#  'titanium oxide',
#  'titanium(iv) oxide',
#  'trans fats',
#  'trichlorosucrose',
#  'vegetable oil brominate',
#  'yellow 5',
#  'yellow 6',
#  'yellow dye no. 5',
#  'yellow dye no. 6'}

# %%
#function to assign health_label based on the presence of bad ingredients in food database ingredient_list

def health_label(ingredients_text):
    # split the preprocessed ingredient text
    product_ingredients = set(ingredients_text.split(', '))
    # discard any empty strings 
    product_ingredients.discard('')
    # check for product ingredients in the set of bad ingredients
    if product_ingredients & bad_ingredients_set:
        return 'not healthy'
    else:
        return 'healthy'

# %%
df_food['health_label'] = df_food['processed_ingredients'].apply(assign_health_label)
df_food.head()
# Out:
#                                brands                            product_name  \
# 0                         Mutti,POLPA                        pulpe de tomates
# 1                   Maïzena, Unilever  Maizena Fleur de Maïs Sans Gluten 400g
# 2                             Barilla                        Lasagne all'uovo
# 3                              Tipiak                  Fine chapelure de pain
# 4  Zespri,Sungold,Catania,ALDI Zespri                            Kiwi Sungold
#
#                                           categories  \
# 0  Pflanzliche Lebensmittel und Getränke,Pflanzli...
# 1  Plant-based foods and beverages, Plant-based f...
# 2  Cibi e bevande a base vegetale, Cibi a base ve...
# 3  Aliments et boissons à base de végétaux,Alimen...
# 4  Aliments et boissons à base de végétaux,Alimen...
#
#                                            countries  \
# 0  Australien,Österreich,Belgien,Kanada,Frankreic...
# 1  Belgique, Canada, France, Martinique, La Réuni...
# 2  Belgium,Canada,Croatia,France,Germany,Greece,H...
# 3                                      Canada,France
# 4  Belgique,Canada,France,Allemagne,Pologne,Espag...
#
#                                 food_groups_tags    food_groups  \
# 0  ['en:fruits-and-vegetables', 'en:vegetables']  en:vegetables
# 1      ['en:cereals-and-potatoes', 'en:cereals']     en:cereals
# 2      ['en:cereals-and-potatoes', 'en:cereals']     en:cereals
# 3        ['en:cereals-and-potatoes', 'en:bread']       en:bread
# 4      ['en:fruits-and-vegetables', 'en:fruits']      en:fruits
#
#                                     ingredients_text  \
# 0                               tomatoes 99.8%, salt
# 1                                    Amidon de maïs.
# 2  Semola di grano duro, uova fresche di categori...
# 3  Farine de blé (gluten), sel, levure, Traces po...
# 4                                          Kiwifruit
#
#                      category_name country  \
# 0  Plant-based foods and beverages  canada
# 1  Plant-based foods and beverages  canada
# 2  Plant-based foods and beverages  canada
# 3  Plant-based foods and beverages  canada
# 4  Plant-based foods and beverages  canada
#
#                                processed_ingredients health_label
# 0                               tomatoes 99.8%, salt      healthy
# 1                                    amidon de maïs.      healthy
# 2  semola di grano duro, uova fresche di categori...      healthy
# 3  farine de blé (gluten), sel, levure, traces po...      healthy
# 4                                          kiwifruit      healthy

# %%
#check for unhealthy food labels
unhealthy_entries = df_food[df_food['health_label'] == 'not healthy']
unhealthy_entries
# Out:
#                      brands                               product_name  \
# 18     Post, Shredded Wheat  Spoon Size Shredded Wheat & Bran - Canada
# 52                    Prime                    Ice Pop Hydration Drink
# 93                    Prime             Blue Raspberry Hydration Drink
# 94               D'Italiano          Original Thick Sliced White Bread
# 196                    Kara                      UHT Coconut Cream 24%
# ...                     ...                                        ...
# 25634                Auchan                         Festonate Fromages
# 25678                Auchan                        Festonate carbonara
# 25693                Auchan   Tagliatelles carbonara aux lardons fumés
# 25696                 Daiya            Dairy-Free Cheddar Mac & Cheese
# 25702                Auchan   Tagliatelles carbonara aux lardons fumés
#
#                                               categories  \
# 18     Plant-based foods and beverages, Plant-based f...
# 52     Plant-based foods and beverages, Beverages, Pl...
# 93     Plant-based foods and beverages, Beverages, Pl...
# 94     Plant-based foods and beverages, Plant-based f...
# 196    Plantaardige levensmiddelen en dranken,Dranken...
# ...                                                  ...
# 25634                                   en:instant-pasta
# 25678  Plats préparés, Plats à base de pâtes, Pâtes i...
# 25693  Plats préparés, Plats à base de pâtes, Plats p...
# 25696  Plant-based foods and beverages, Plant-based f...
# 25702  Plats préparés, Plats à base de pâtes, Plats p...
#
#                                      countries  \
# 18                               Canada, World
# 52                                      Canada
# 93                                      Canada
# 94                               France,Canada
# 196    Wereld,en:Franciaország,en:Magyarország
# ...                                        ...
# 25634                            France, Monde
# 25678                            France, Monde
# 25693                            France, Monde
# 25696              France,United States, World
# 25702                            France, Monde
#
#                                         food_groups_tags  \
# 18     ['en:cereals-and-potatoes', 'en:breakfast-cere...
# 52            ['en:beverages', 'en:sweetened-beverages']
# 93     ['en:beverages', 'en:artificially-sweetened-be...
# 94               ['en:cereals-and-potatoes', 'en:bread']
# 196    ['en:beverages', 'en:plant-based-milk-substitu...
# ...                                                  ...
# 25634        ['en:composite-foods', 'en:one-dish-meals']
# 25678        ['en:composite-foods', 'en:one-dish-meals']
# 25693        ['en:composite-foods', 'en:one-dish-meals']
# 25696        ['en:composite-foods', 'en:one-dish-meals']
# 25702        ['en:composite-foods', 'en:one-dish-meals']
#
#                                food_groups  \
# 18                    en:breakfast-cereals
# 52                  en:sweetened-beverages
# 93     en:artificially-sweetened-beverages
# 94                                en:bread
# 196        en:plant-based-milk-substitutes
# ...                                    ...
# 25634                    en:one-dish-meals
# 25678                    en:one-dish-meals
# 25693                    en:one-dish-meals
# 25696                    en:one-dish-meals
# 25702                    en:one-dish-meals
#
#                                         ingredients_text  \
# 18                    Whole grain wheat, Wheat bran, BHT
# 52     Filtered water, Coconut water from concentrate...
# 93     Filtered water, Coconut water from concentrate...
# 94     Enriched wheat flour, Water, Sugar, Yeast, Veg...
# 196    natural coconut cream (99,9%), xanthan gum, gu...
# ...                                                  ...
# 25634  Pâtes aux œufs cuites 45,7% (eau, semoule de B...
# 25678  Pâtes aux œufs cuites 42% (semoule de BLÉ dur,...
# 25693  Pâtesaux ŒUFS cuites 46% (eau, semoule deBLÉ d...
# 25696  Brown rice pasta (whole grain brown rice, rice...
# 25702  Pâtes aux ŒUFS cuites 46% (eau,semoule de BLÉ ...
#
#                          category_name country  \
# 18     Plant-based foods and beverages  canada
# 52     Plant-based foods and beverages  canada
# 93     Plant-based foods and beverages  canada
# 94     Plant-based foods and beverages  canada
# 196    Plant-based foods and beverages   world
# ...                                ...     ...
# 25634                     Pasta dishes   world
# 25678                     Pasta dishes   world
# 25693                     Pasta dishes   world
# 25696                     Pasta dishes   world
# 25702                     Pasta dishes   world
#
#                                    processed_ingredients health_label
# 18                    whole grain wheat, wheat bran, bht  not healthy
# 52     filtered water, coconut water from concentrate...  not healthy
# 93     filtered water, coconut water from concentrate...  not healthy
# 94     enriched wheat flour, water, sugar, yeast, veg...  not healthy
# 196    natural coconut cream (99, 9%), xanthan gum, g...  not healthy
# ...                                                  ...          ...
# 25634  pâtes aux œufs cuites 45, 7% (eau, semoule de ...  not healthy
# 25678  pâtes aux œufs cuites 42% (semoule de blé dur,...  not healthy
# 25693  pâtesaux œufs cuites 46% (eau, semoule deblé d...  not healthy
# 25696  brown rice pasta (whole grain brown rice, rice...  not healthy
# 25702  pâtes aux œufs cuites 46% (eau, semoule de blé...  not healthy
#
# [1646 rows x 11 columns]

# %%
df_food.to_csv('../data/final_data.csv')
